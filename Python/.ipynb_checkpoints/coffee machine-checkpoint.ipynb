# %% [markdown]
# 커피자판기 만들기
#
# 금액 투입
# 커피 선택
# 커피 출력
# 잔액 출력
# 동전 : 500, 100, 1000 등등
#
# 1) 관리자/ 사용자 기능 구현
#
# 예시)
# 관리자
# 커피 재료 : 10잔 -> 10잔 만들 수 있음
# 동전 : 500원 20개, 100원 50개 1000원 30장
# 커피 없음 -> 품절 출력
#
# 사용자
# 금액투입
# 커피 선택
# 거스름 돈 받을 것인지 추가 구매 할 것인지
#
#
#
# 실행 예시
#
# 선택하세요
# (1) 관리자 (2)사용자
# 입력 : 1
#
# (1) 커피재료 (2) 동전 투입
# 입력 : 1
#
# 커피 충전?
# 입력 : 10
# 10 잔이 충전되었습니다

# %%
# 관리자

# %%
def m_coffee():
    t = input("추가하시겠습니까? Yes :y  No :n\n")
    print(t)
    if t == 'y':
        quit = True
        while quit:
            menu = input('어떤 커피를 추가하시겠습니까? 1.믹스 2.블랙 3.블랙with설탕')
            if menu == '1':
                a = int(input('몇개를 추가 하시겠습니까?\n'))
                num_coffee1 += a
                b = input("계속 추가하시겠습니까? Yes:y No:n")
                if b == 'n':
                    quit = False
            elif menu == '2':
                a = int(input('몇개를 추가 하시겠습니까?\n'))
                num_coffee2 += a
                b = input("계속 추가하시겠습니까? Yes:y No:n")
                if b == 'n':
                    quit = False
            elif menu == '3':
                a = int(input('몇개를 추가 하시겠습니까?\n'))
                num_coffee3 += a
                b = input("계속 추가하시겠습니까? Yes:y No:n")
                if b == 'n':
                    quit = False
            # 추가한 수가 음수인지 체크 안해도 되겠지??
    elif t == 'n':
        manger()
    else:
        print("잘못 입력하였습니다",'다시 입력하세요',sep = '\n')
        m_coffee()

# %%
def m_money():
    t = input("추가하시겠습니까? Yes :y  No :n\n")
    if t =='y':
        quit = True
        while quit:
            coin = input("1.100원 2.500원 3.1000원")
            if coin == '1':
                print("남은 100원의 개수는 %d개 입니다"%int(machine100))
                a = int(input("얼마를 추가하겠습니까?"))
                machine100 += int(a/100)
                b = input("계속 추가하시겠습니까? Yes:y No:n")
                if b == 'n':
                    quit = False
            elif coin == '2':
                print("남은 500원의 개수는 %d개 입니다"%int(machine500))
                a = int(input("얼마를 추가하겠습니까?"))
                machine500 += int(a/500)
                b = input("계속 추가하시겠습니까? Yes:y No:n")
                if b == 'n':
                    quit = False
            elif coin == '3':
                print("남은 1000원의 개수는 %d개 입니다"%int(machine1000))
                a = int(input("얼마를 추가하겠습니까?"))
                machine1000 += int(a/1000)
                b = input("계속 추가하시겠습니까? Yes:y No:n")
                if b == 'n':
                    quit = False
            else:
                print("잘못 입력하였습니다")
                # 재귀 안함
    else:
        manager()

# %%
def manager():
    m_do = input('1. 커피관리 2.동전관리 3.이전 페이지로\n')
    if m_do == '1':
        print("남은 커피는 믹스 {}잔, 블랙 {}잔, 연한블랙 {}잔 입니다".format(num_coffee1,num_coffee2,num_coffee3))
        m_coffee() 
    elif m_do == '2':
        print("100원 {}개, 500원 {}개, 100원 {}개".format(int(machine100),int(machine500),int(machine1000)))
        print("총 %d원 남았습니다"%(machine100*100+machine500*500+machine1000*1000))
        m_money()
    elif m_do == '3':
        CoffeeMachine()
    else:
        print("잘못 입력하였습니다",'다시 입력하세요',sep = '\n')
        manager()

# %%
# 사용자

# %%
def u_money():
    quit = True
    while quit:
        t = input("투입할 돈의 타입을 정해주세요.\n 1.100 2.500 3.1000\n")
        if t == '1':
            a = input('얼마를 넣으실건가요?')
            user100 += a
            # 넣은 금액 알려주기??필요한가??
            b = input("계속 추가하시겠습니까? Yes:y No:n")
            if b == 'n':
                quit = False
        elif t =='2':
            a = input('얼마를 넣으실건가요?')
            user500 += a
            b = input("계속 추가하시겠습니까? Yes:y No:n")
            if b == 'n':
                quit = False
        elif t == '3':
            a = input('얼마를 넣으실건가요?')
            user1000 += a
            b = input("계속 추가하시겠습니까? Yes:y No:n")
            if b == 'n':
                quit = False
        else:
            print('worng')
        user_money = user100 + user500 + user1000
        print("투입하신 총 금액은 %d원 입니다"%user_money)

# %%
def machine(menu, num):
    if menu == 1:
        if num*coffee1 < user_money:
            print("금액이 부족합니다")
        elif num_coffee1 < num:
            print("커피가 %d개 부족합니다. 죄송합니다"%num-num_coffee1)
        else:
            change = user_money - num*coffee1
            cal(change)
    elif menu == 2:
        if num*coffee2 < user_money:
            print("금액이 부족합니다")
        elif num_coffee2 < num:
            print("커피가 %d개 부족합니다. 죄송합니다"%num-num_coffee2)
        else:
            change = user_money - num*coffee2
            cal(change)        
    elif menu == 3:
        if num*coffee3 < user_money:
            print("금액이 부족합니다")
        elif num_coffee3 < num:
            print("커피가 %d개 부족합니다. 죄송합니다"%num-num_coffee3)
        else:
            change = user_money - num*coffee3
            cal(change)
    else:
        print('잘못된 커피 메뉴입니다')

# %%
def cal(chanage):
    change1000 = change//1000
    change500 = (change - change1000*1000)//500
    change100 = (change - change1000*1000 - change500*500)//100
            
    if not (machine1000 >= change1000 and machine500 >= change500 and machine100 >= change100):
        if machine1000 < change1000:
            need500 = (machine1000 -change1000)*2
            change500 += need500

        if machine500 < change500:
            need100 = (machine500 -change500)*5
            change100 += need100

        if machine100 < change100:
            need = change100-machine100
            if machine1000 - change1000 - need//10 < 0:
                if machine500 - change500-abs(machine1000 - change1000 - need//10)*2 < 0:
                    print("기계에 잔돈이 부족합니다. 죄송합니다")
            
    else:
        print("받을 금액은 100원 {}개, 500원 {}개, 1000원 {}장, 총 {}원입니다.".format(change100,change500,change1000))

# %%
def u_coffee():
    quit = True
    while quit:
        print('1.믹스 {}원 2.블랙 {}원 3.블랙with설탕 {}원'.format(coffee1,coffee2,coffee3))
        menu = int(input("어떤 커피를 원하십니까?"))
        num = input('몇 잔을 원하나요?')
        machine(menu,num)
        
        b = input("커피를 (추가)선택 하시겠습니까? Yes:y No:n")
        if b == 'n':
            quit = False

# %%
def user():
    user_quit = True
    while user_quit:
        u_do = input('1. 금액투입 2.커피선택\n')
        if u_do == '1':
            print("현재 투입금액은 %d원 입니다"%user_money)
            u_money()
            b = input("계속 하시겠습니까? Yes:y No:n")
            if b == 'n':
                user_quit = False
        elif u_do == '2':
            u_coffee()
            b = input("계속 하시겠습니까? Yes:y No:n")
            if b == 'n':
                user_quit = False
        else:
            print("잘못 입력하였습니다",'다시 입력하세요',sep = '\n')
    CoffeeMachine()

# %%
def CoffeeMachine():
    who = input('당신은 누구입니까?\n1.관리자 2.사용자\n')
    if who == '1':
        manager()
    elif who == '2':
        user()
    else:
        print("잘못 입력하였습니다",'다시 입력하세요',sep = '\n')
        CoffeMachine()

# %%
#자판기 안에 있는 돈 개수
global machine100 
global machine500 
global machine1000 

# 커피 개수
global num_coffee1
global num_coffee2 
global num_coffee3

#사용자가 투입한 금액
global user_money 
global user100 
global user500 
global user1000 






machine100 = 0
machine500 = 0
machine1000 = 0

# 커피 개수
num_coffee1 = 0
num_coffee2 = 0
num_coffee3 = 0

#사용자가 투입한 금액
user_money = 0
user100 = 0
user500 = 0
user1000 = 0

# 커피가격
coffee1 = 300
coffee2 = 400
coffee3 = 500

CoffeeMachine()
# Out:
# 당신은 누구입니까?
# 1.관리자 2.사용자
# 1
# 1. 커피관리 2.동전관리 3.이전 페이지로
# 1
# 남은 커피는 믹스 0잔, 블랙 0잔, 연한블랙 0잔 입니다
# 추가하시겠습니까? Yes :y  No :n
# y
# y
# 어떤 커피를 추가하시겠습니까? 1.믹스 2.블랙 3.블랙with설탕1
# 몇개를 추가 하시겠습니까?
# 10
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-50-2d4bcabdfa54> in <module>
#      40 coffee3 = 500
#      41
# ---> 42 CoffeeMachine()
#
# <ipython-input-45-695e69b2a9f6> in CoffeeMachine()
#       2     who = input('당신은 누구입니까?\n1.관리자 2.사용자\n')
#       3     if who == '1':
# ----> 4         manager()
#       5     elif who == '2':
#       6         user()
#
# <ipython-input-36-1f86172cd85e> in manager()
#       3     if m_do == '1':
#       4         print("남은 커피는 믹스 {}잔, 블랙 {}잔, 연한블랙 {}잔 입니다".format(num_coffee1,num_coffee2,num_coffee3))
# ----> 5         m_coffee()
#       6     elif m_do == '2':
# ...

# %%
a = True
while a:
    test = 0
    for i in range(5):
        test += i
        print(test)
        if test > 9:
            a = False
# Out:
# 0
# 1
# 3
# 6
# 10
